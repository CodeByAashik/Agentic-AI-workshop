# %%
import os
from typing import List, Any
from langchain_ollama import ChatOllama
from langchain_community.document_loaders import PyMuPDFLoader, DirectoryLoader
from langchain_chroma import Chroma
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

# --- VECTOR STORE LOGIC ---
class ChromaVectorStore:
    def __init__(self, persist_dir: str = "chroma_store",
                 embedding_model_name: str = "all-MiniLM-L6-v2"):
        self.persist_dir = persist_dir
        self.embedding_function = HuggingFaceEmbeddings(model_name=embedding_model_name)
        self.vectorstore = None
        
        # Load existing store if it exists
        if os.path.exists(os.path.join(self.persist_dir, "chroma.sqlite3")):
            self.vectorstore = Chroma(persist_directory=self.persist_dir,
                                      embedding_function=self.embedding_function)

    def build_from_documents(self, documents: List[Any]):
        text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
        chunks = text_splitter.split_documents(documents)
        self.vectorstore = Chroma.from_documents(
            documents=chunks,
            embedding=self.embedding_function,
            persist_directory=self.persist_dir
        )

# --- LCEL RAG IMPLEMENTATION ---
class RAGSearch:
    def __init__(self, pdf_docs: List[Any]):
        # Initialize Vector Store
        self.cvs = ChromaVectorStore()
        if self.cvs.vectorstore is None:
            self.cvs.build_from_documents(pdf_docs)
        
        # Define Retriever as a Runnable
        self.retriever = self.cvs.vectorstore.as_retriever(search_kwargs={"k": 3})

        # Initialize LLM
        self.llm = ChatOllama(model="llama3.2:latest")
        # Define Prompt Template
        template = """Answer the question based only on the following context:
        {context}

        Question: {question}
        """
        self.prompt = ChatPromptTemplate.from_template(template)

        # --- THE LCEL PIPELINE ---
        # This replaces manual loops and formatting
        self.rag_chain = (
            {"context": self.retriever | self._format_docs, "question": RunnablePassthrough()}
            | self.prompt
            | self.llm
            | StrOutputParser()
        )

    def _format_docs(self, docs):
        return "\n\n".join(doc.page_content for doc in docs)

    def ask(self, query: str):
        return self.rag_chain.invoke(query)

# --- EXECUTION ---
# Ensure a folder named 'pdf-files' exists in your Colab file explorer
if not os.path.exists("pdf-files"):
    os.makedirs("pdf-files")
    print("Please upload your PDFs to the 'pdf-files' folder and run again.")
else:
    loader = DirectoryLoader("pdf-files", glob="**/*.pdf", loader_cls=PyMuPDFLoader)
    docs = loader.load()
    
    if docs:
        rag_system = RAGSearch(pdf_docs=docs)
        
        question = "What does the Part-8 of the constitution talk about? "
        print(rag_system.ask(question))
# Out:
# The context provided only shows 3 instances of "7" with a common text. There is no specific mention of what Part-8 of the constitution talks about. The instances only describe the passage and promulgation of the Constitution, but do not provide any information about its content or structure.

# %%
# !pip install langchain-chroma
# !pip install langchain-ollama
# !pip install langchain-huggingface
# Out:
# Requirement already satisfied: langchain-chroma in g:\anaconda-mms\lib\site-packages (1.1.0)
# Requirement already satisfied: chromadb<2.0.0,>=1.3.5 in g:\anaconda-mms\lib\site-packages (from langchain-chroma) (1.3.7)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.3 in g:\anaconda-mms\lib\site-packages (from langchain-chroma) (1.2.1)
# Requirement already satisfied: numpy>=2.1.0 in g:\anaconda-mms\lib\site-packages (from langchain-chroma) (2.3.5)
# Requirement already satisfied: build>=1.0.3 in g:\anaconda-mms\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.3.0)
# Requirement already satisfied: pydantic>=1.9 in g:\anaconda-mms\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.10.3)
# Requirement already satisfied: pybase64>=1.4.1 in g:\anaconda-mms\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in g:\anaconda-mms\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.38.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in g:\anaconda-mms\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in g:\anaconda-mms\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in g:\anaconda-mms\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in g:\anaconda-mms\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in g:\anaconda-mms\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in g:\anaconda-mms\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.39.1)
# Requirement already satisfied: tokenizers>=0.13.2 in g:\anaconda-mms\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in g:\anaconda-mms\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in g:\anaconda-mms\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in g:\anaconda-mms\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (7.4.0)
# Requirement already satisfied: importlib-resources in g:\anaconda-mms\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in g:\anaconda-mms\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in g:\anaconda-mms\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in g:\anaconda-mms\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in g:\anaconda-mms\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (34.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in g:\anaconda-mms\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (9.0.0)
# Requirement already satisfied: pyyaml>=6.0.0 in g:\anaconda-mms\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in g:\anaconda-mms\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in g:\anaconda-mms\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.11.5)
# Requirement already satisfied: httpx>=0.27.0 in g:\anaconda-mms\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in g:\anaconda-mms\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in g:\anaconda-mms\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.23.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in g:\anaconda-mms\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in g:\anaconda-mms\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.4.59)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in g:\anaconda-mms\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (24.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in g:\anaconda-mms\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in g:\anaconda-mms\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (2.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in g:\anaconda-mms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in g:\anaconda-mms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in g:\anaconda-mms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.23.0)
# Requirement already satisfied: anyio in g:\anaconda-mms\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.12.0)
# Requirement already satisfied: certifi in g:\anaconda-mms\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in g:\anaconda-mms\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.0.9)
# Requirement already satisfied: idna in g:\anaconda-mms\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.7)
# Requirement already satisfied: h11>=0.16 in g:\anaconda-mms\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.16.0)
# Requirement already satisfied: six>=1.5 in g:\anaconda-mms\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in g:\anaconda-mms\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in g:\anaconda-mms\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in g:\anaconda-mms\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in g:\anaconda-mms\lib\site-packages (from pydantic>=1.9->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in g:\anaconda-mms\lib\site-packages (from pydantic>=1.9->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.27.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in g:\anaconda-mms\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in g:\anaconda-mms\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (2.3.0)
# Requirement already satisfied: pyproject_hooks in g:\anaconda-mms\lib\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.2.0)
# Requirement already satisfied: colorama in g:\anaconda-mms\lib\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in g:\anaconda-mms\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in g:\anaconda-mms\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in g:\anaconda-mms\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in g:\anaconda-mms\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.22.3)
# Requirement already satisfied: google-auth>=1.0.1 in g:\anaconda-mms\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.45.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in g:\anaconda-mms\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.8.0)
# Requirement already satisfied: requests-oauthlib in g:\anaconda-mms\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in g:\anaconda-mms\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in g:\anaconda-mms\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in g:\anaconda-mms\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in g:\anaconda-mms\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in g:\anaconda-mms\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.4.8)
# Requirement already satisfied: coloredlogs in g:\anaconda-mms\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in g:\anaconda-mms\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (25.9.23)
# Requirement already satisfied: protobuf in g:\anaconda-mms\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.29.3)
# Requirement already satisfied: sympy in g:\anaconda-mms\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.13.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in g:\anaconda-mms\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in g:\anaconda-mms\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.21.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in g:\anaconda-mms\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in g:\anaconda-mms\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in g:\anaconda-mms\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in g:\anaconda-mms\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.60b1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in g:\anaconda-mms\lib\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in g:\anaconda-mms\lib\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in g:\anaconda-mms\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.1.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in g:\anaconda-mms\lib\site-packages (from tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.36.0)
# Requirement already satisfied: filelock in g:\anaconda-mms\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in g:\anaconda-mms\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2025.3.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in g:\anaconda-mms\lib\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (8.1.8)
# Requirement already satisfied: httptools>=0.6.3 in g:\anaconda-mms\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in g:\anaconda-mms\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.1.0)
# Requirement already satisfied: watchfiles>=0.13 in g:\anaconda-mms\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in g:\anaconda-mms\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in g:\anaconda-mms\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (10.0)
# Requirement already satisfied: pyreadline3 in g:\anaconda-mms\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.5.4)
# Requirement already satisfied: oauthlib>=3.0.0 in g:\anaconda-mms\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in g:\anaconda-mms\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.3.0)
# Requirement already satisfied: langchain-ollama in g:\anaconda-mms\lib\site-packages (1.0.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in g:\anaconda-mms\lib\site-packages (from langchain-ollama) (1.2.1)
# Requirement already satisfied: ollama<1.0.0,>=0.6.0 in g:\anaconda-mms\lib\site-packages (from langchain-ollama) (0.6.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in g:\anaconda-mms\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in g:\anaconda-mms\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.4.59)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in g:\anaconda-mms\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in g:\anaconda-mms\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.10.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in g:\anaconda-mms\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in g:\anaconda-mms\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in g:\anaconda-mms\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (4.12.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in g:\anaconda-mms\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in g:\anaconda-mms\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in g:\anaconda-mms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in g:\anaconda-mms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in g:\anaconda-mms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in g:\anaconda-mms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in g:\anaconda-mms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.23.0)
# Requirement already satisfied: anyio in g:\anaconda-mms\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (4.12.0)
# Requirement already satisfied: certifi in g:\anaconda-mms\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in g:\anaconda-mms\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (1.0.9)
# Requirement already satisfied: idna in g:\anaconda-mms\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.7)
# Requirement already satisfied: h11>=0.16 in g:\anaconda-mms\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in g:\anaconda-mms\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in g:\anaconda-mms\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.27.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in g:\anaconda-mms\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in g:\anaconda-mms\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.3.0)
# Requirement already satisfied: langchain-huggingface in g:\anaconda-mms\lib\site-packages (1.2.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.33.4 in g:\anaconda-mms\lib\site-packages (from langchain-huggingface) (0.36.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.0 in g:\anaconda-mms\lib\site-packages (from langchain-huggingface) (1.2.1)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in g:\anaconda-mms\lib\site-packages (from langchain-huggingface) (0.22.1)
# Requirement already satisfied: filelock in g:\anaconda-mms\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in g:\anaconda-mms\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in g:\anaconda-mms\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in g:\anaconda-mms\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (6.0.2)
# Requirement already satisfied: requests in g:\anaconda-mms\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in g:\anaconda-mms\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in g:\anaconda-mms\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (4.12.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in g:\anaconda-mms\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in g:\anaconda-mms\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.4.59)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in g:\anaconda-mms\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (2.10.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in g:\anaconda-mms\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (9.0.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in g:\anaconda-mms\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in g:\anaconda-mms\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in g:\anaconda-mms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in g:\anaconda-mms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in g:\anaconda-mms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in g:\anaconda-mms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.23.0)
# Requirement already satisfied: anyio in g:\anaconda-mms\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (4.12.0)
# Requirement already satisfied: certifi in g:\anaconda-mms\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in g:\anaconda-mms\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (1.0.9)
# Requirement already satisfied: idna in g:\anaconda-mms\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (3.7)
# Requirement already satisfied: h11>=0.16 in g:\anaconda-mms\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in g:\anaconda-mms\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in g:\anaconda-mms\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (2.27.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in g:\anaconda-mms\lib\site-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in g:\anaconda-mms\lib\site-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (2.3.0)
# Requirement already satisfied: colorama in g:\anaconda-mms\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (0.4.6)

# %%
# !pip install langchain-core langchain-community pymupdf chromadb langchain_google_genai
# Out:
# Requirement already satisfied: langchain-core in g:\anaconda-mms\lib\site-packages (1.2.1)
# Requirement already satisfied: langchain-community in g:\anaconda-mms\lib\site-packages (0.4.1)
# Requirement already satisfied: pymupdf in g:\anaconda-mms\lib\site-packages (1.26.7)
# Requirement already satisfied: chromadb in g:\anaconda-mms\lib\site-packages (1.3.7)
# Requirement already satisfied: langchain_google_genai in g:\anaconda-mms\lib\site-packages (4.0.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in g:\anaconda-mms\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in g:\anaconda-mms\lib\site-packages (from langchain-core) (0.4.59)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in g:\anaconda-mms\lib\site-packages (from langchain-core) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in g:\anaconda-mms\lib\site-packages (from langchain-core) (2.10.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in g:\anaconda-mms\lib\site-packages (from langchain-core) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in g:\anaconda-mms\lib\site-packages (from langchain-core) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in g:\anaconda-mms\lib\site-packages (from langchain-core) (4.12.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in g:\anaconda-mms\lib\site-packages (from langchain-core) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in g:\anaconda-mms\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in g:\anaconda-mms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in g:\anaconda-mms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in g:\anaconda-mms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in g:\anaconda-mms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in g:\anaconda-mms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.23.0)
# Requirement already satisfied: anyio in g:\anaconda-mms\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (4.12.0)
# Requirement already satisfied: certifi in g:\anaconda-mms\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in g:\anaconda-mms\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.9)
# Requirement already satisfied: idna in g:\anaconda-mms\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.7)
# Requirement already satisfied: h11>=0.16 in g:\anaconda-mms\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in g:\anaconda-mms\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in g:\anaconda-mms\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (2.27.1)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in g:\anaconda-mms\lib\site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in g:\anaconda-mms\lib\site-packages (from langchain-community) (2.0.39)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in g:\anaconda-mms\lib\site-packages (from langchain-community) (3.11.10)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in g:\anaconda-mms\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in g:\anaconda-mms\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in g:\anaconda-mms\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in g:\anaconda-mms\lib\site-packages (from langchain-community) (2.3.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in g:\anaconda-mms\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in g:\anaconda-mms\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in g:\anaconda-mms\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in g:\anaconda-mms\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in g:\anaconda-mms\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in g:\anaconda-mms\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in g:\anaconda-mms\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in g:\anaconda-mms\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in g:\anaconda-mms\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in g:\anaconda-mms\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in g:\anaconda-mms\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in g:\anaconda-mms\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in g:\anaconda-mms\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in g:\anaconda-mms\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in g:\anaconda-mms\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in g:\anaconda-mms\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.0.0)
# Requirement already satisfied: build>=1.0.3 in g:\anaconda-mms\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in g:\anaconda-mms\lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in g:\anaconda-mms\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.38.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in g:\anaconda-mms\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in g:\anaconda-mms\lib\site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in g:\anaconda-mms\lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in g:\anaconda-mms\lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in g:\anaconda-mms\lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: tokenizers>=0.13.2 in g:\anaconda-mms\lib\site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in g:\anaconda-mms\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in g:\anaconda-mms\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in g:\anaconda-mms\lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in g:\anaconda-mms\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in g:\anaconda-mms\lib\site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in g:\anaconda-mms\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in g:\anaconda-mms\lib\site-packages (from chromadb) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in g:\anaconda-mms\lib\site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in g:\anaconda-mms\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: rich>=10.11.0 in g:\anaconda-mms\lib\site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in g:\anaconda-mms\lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: six>=1.5 in g:\anaconda-mms\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in g:\anaconda-mms\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in g:\anaconda-mms\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in g:\anaconda-mms\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in g:\anaconda-mms\lib\site-packages (from langchain_google_genai) (1.2.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.53.0 in g:\anaconda-mms\lib\site-packages (from langchain_google_genai) (1.55.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in g:\anaconda-mms\lib\site-packages (from google-auth[requests]<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.53.0->langchain_google_genai) (2.45.0)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in g:\anaconda-mms\lib\site-packages (from google-genai<2.0.0,>=1.53.0->langchain_google_genai) (15.0.1)
# Requirement already satisfied: sniffio in g:\anaconda-mms\lib\site-packages (from google-genai<2.0.0,>=1.53.0->langchain_google_genai) (1.3.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in g:\anaconda-mms\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.53.0->langchain_google_genai) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in g:\anaconda-mms\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.53.0->langchain_google_genai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in g:\anaconda-mms\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.53.0->langchain_google_genai) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in g:\anaconda-mms\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.53.0->langchain_google_genai) (0.4.8)
# Requirement already satisfied: pyproject_hooks in g:\anaconda-mms\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in g:\anaconda-mms\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in g:\anaconda-mms\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in g:\anaconda-mms\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in g:\anaconda-mms\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.22.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in g:\anaconda-mms\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in g:\anaconda-mms\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in g:\anaconda-mms\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: coloredlogs in g:\anaconda-mms\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in g:\anaconda-mms\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in g:\anaconda-mms\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.3)
# Requirement already satisfied: sympy in g:\anaconda-mms\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in g:\anaconda-mms\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in g:\anaconda-mms\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in g:\anaconda-mms\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in g:\anaconda-mms\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in g:\anaconda-mms\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in g:\anaconda-mms\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.60b1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in g:\anaconda-mms\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in g:\anaconda-mms\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in g:\anaconda-mms\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in g:\anaconda-mms\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.36.0)
# Requirement already satisfied: filelock in g:\anaconda-mms\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in g:\anaconda-mms\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.3.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in g:\anaconda-mms\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: httptools>=0.6.3 in g:\anaconda-mms\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.13 in g:\anaconda-mms\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: humanfriendly>=9.1 in g:\anaconda-mms\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in g:\anaconda-mms\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: oauthlib>=3.0.0 in g:\anaconda-mms\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in g:\anaconda-mms\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
